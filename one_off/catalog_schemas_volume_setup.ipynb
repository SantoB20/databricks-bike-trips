# %%
spark.sql("create catalog if not exists bikes")

# %%
#Creation of schemas based on medallion architecture
spark.sql("create schema if not exists bikes.00_landing")
spark.sql("create schema if not exists bikes.01_bronze")
spark.sql("create schema if not exists bikes.02_silver")
spark.sql("create schema if not exists bikes.03_gold")

# %%
#Creation of volume where all data files from Divvy and Bay Wheels will be stored
spark.sql("create volume if not exists bikes.00_landing.data_sources")
